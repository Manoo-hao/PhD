# %% [markdown]
# In addition to the original script, 2_generate_TP, this script does a blast search of selected_tp_genes against temp_neg_genomes and filters out all genomes that have a hit.
#
#
# This script generates the 2 remaining files required for input:
# - True positive genes (nucleotide fasta)
# - protein alignment (amino acid fasta)
# IMPORTANTLY, these 2 files are created from non-overlapping sequences!
#
#
# And also moves the corresponding files to new directories so that coverage tables can be generated from them.
#
# In the first cell specify:
# - BGC type (This name must stay constant throughout the scripts)
# - select_neg_genomes, i.e. the amount of negative genomes to be transferred to the neg_genomes directory
# - select_pos_genomes, i.e. the amount of positive genomes to be transferred to the pos_genomes directory and to generate the tp_genes file from (the surplus amount will be used to generate the protein alignment from)
# - pos_isolation_source_filter, if these terms are found in the isolation_source column of the positive samples in the summary file, they will be scored higher in a scoring column, i.e. samples from a known and desired isolation source will be used preferentially.
# - neg_isolation_source_filter, accordingly
# - avoid_list. These terms are scored with a 0, end at the bottom of the table, and will be picked last. This is useful when an uncommon gene is searched for and more, and/or more tenuous isolation sources have been allowed during download. These are generally words that contain one of the search terms, e.g. 'sea' in 'diseased'.

# %% [markdown]
# Modify in such a way that TP genes are used as query against all individual negative genomes. Negative genomes are only moved from temp directory to neg_genomes directory if the blast search comes back negative

# %%
BGC_type = 'YcaO'
select_neg_genomes = 140
select_pos_genomes = 10

avoid_list = ['', 'isolation_source not annotated', 'diseased', 'mice', 'spice', 'septicemic', 'research', 'crevice']
#these are identical to first script, but don't have to be
pos_isolation_source_filter =  ['marine', 'sea', 'sponge', 'ocean', 'porifera', 'seafloor','sediment', 'water', 'tidal', 'coral', 'reef', 'coast', 'ship', 'fish', 'aquaculture', 'atlantic', 'pacific', 'mediterranean', 'baltic', 'pond', 'river', 'ice', 'carribean', 'lake', 'fjord', 'marina', 'hydro', 'algal', 'algae']
neg_isolation_source_filter = ['marine', 'sea', 'sponge', 'ocean', 'porifera', 'seafloor', 'sediment', 'water', 'tidal', 'coral', 'reef', 'coast', 'ship', 'fish', 'aquaculture', 'atlantic', 'pacific', 'mediterranean', 'baltic', 'pond', 'river', 'ice', 'carribean', 'lake', 'fjord', 'marina', 'hydro', 'algal', 'algae']

# %%
import os
from os import listdir, mkdir
from os.path import isfile, join
from pathlib import Path
import pandas as pd
from pandas.errors import EmptyDataError
import random
import glob
import warnings

# %%
def makedir(dirpath):
    if os.path.isdir(dirpath):
        print(dirpath,'exists already')
    else:
        print('Making', dirpath)    
        os.mkdir(dirpath)

        
# Defining paths for required directory structure for input and output files relative to parent directory
#parent_dir='/media/manu/RiPP_Prioritiser/'
#will make directories relative to the path the notebook was opened in
parent_dir= !echo $(pwd)
BGC_path=os.path.join(parent_dir[0], BGC_type)
neg_genomes_path=os.path.join(BGC_path, 'base_genomes/temp_neg_genomes')
pos_genomes_path=os.path.join(BGC_path, 'base_genomes/temp_pos_genomes')
output_neg_path=os.path.join(BGC_path, 'base_genomes/neg_genomes')
output_pos_path=os.path.join(BGC_path, 'base_genomes/pos_genomes')
neg_blast_path=os.path.join(BGC_path, 'base_genomes/neg_blast')
neg_blast_db_path=os.path.join(BGC_path, 'base_genomes/neg_blast/databases')
neg_blast_results_path=os.path.join(BGC_path, 'base_genomes/neg_blast/results')


# Calling function to make directories if they don't exist yet
makedir(output_neg_path)
makedir(output_pos_path)
makedir(neg_blast_path)
makedir(neg_blast_db_path)
makedir(neg_blast_results_path)

os.chdir(BGC_path)
# Out:
# Making /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# Making /media/manu/RiPP_Prioritiser/YcaO/base_genomes/pos_genomes
# Making /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_blast
# Making /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_blast/databases
# Making /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_blast/results

# %%
# Generating a report file for this script
with open(BGC_path+'/'+'report_2_generate_tp.txt', 'w') as f:
    f.write('Output directory is: '+BGC_path+'\n')
    f.write('\nBGC_type = '+BGC_type)
    f.write('\nselect_neg_genomes = '+str(select_neg_genomes))
    f.write('\nselect_pos_genomes = '+str(select_pos_genomes))
    f.write('\navoid_list = '+str(avoid_list))
    f.write('\nneg_isolation_source_filter = '+str(neg_isolation_source_filter))
    f.write('\npos_isolation_source_filter = '+str(pos_isolation_source_filter)+'\n')

# %%
# load summary table into data frame () output from 1.)
summary_file = pd.read_csv('summary.tsv', sep='\t')

# %% [markdown]
# Change order of tables to prioritize samples that have an isolation source

# %%
warnings.filterwarnings('ignore')

#filter positives and drop all duplicate protein sequences originating from different organisms
pos_mask = (summary_file['dir'] == '+')
pos_df = summary_file[pos_mask]
pos_df.drop_duplicates(subset='protein_id', keep=False, inplace=True)


#filter negatives
neg_mask = (summary_file['dir'] == '-')
neg_df = summary_file[neg_mask]

#scoring words in isolation source so as to preferentially pick samples with chosen isolation sources

def custom_sorting(source,isolation_source_filter):
    score = 1
    if isolation_source_filter=='pos':
        for word in pos_isolation_source_filter:
            if word in source:
                score +=1
        for word in avoid_list:
            if source == word:
                score=0
    elif isolation_source_filter=='neg':
        for word in neg_isolation_source_filter:
            if word in source:
                score +=1
        for word in avoid_list:
            if source == word:
                score=0
    return score


pos_df['scoring_column'] = pos_df.apply(lambda x: custom_sorting(x['isolation_source'],'pos'),axis=1)
neg_df['scoring_column'] = neg_df.apply(lambda x: custom_sorting(x['isolation_source'],'neg'),axis=1)

pos_df.sort_values(by=['scoring_column'], axis=0, ascending=False, inplace=True)
neg_df.sort_values(by=['scoring_column'], axis=0, ascending=False, inplace=True)

# %%
#Split positive genomes into 2 bins, one goes towards tp-genes and is the pos-genomes used for synthesising metagenomes
#the other one constitutes a source of protein sequences for alignment as an input file

# Genomes selected in such a way that they are from the top of the pre-sorted pos_df
unique_pos_df = pos_df.drop_duplicates(subset='assembly', inplace=False)
selected_tp_genomes = list(unique_pos_df.iloc[:,1])[0:select_pos_genomes]
remaining_pos_genomes = list(unique_pos_df.iloc[:,1])[select_pos_genomes:]

with open(BGC_path+'/'+'report_2_generate_tp.txt', 'a') as f:
    f.write('\nselected_tp_genomes are:\n')
    f.write(str(selected_tp_genomes)+'\n')

#select genomes and isolate GCF number from them, move selected tp genomes to final pos_genomes directory
for genome in selected_tp_genomes:
    print('moving positive', genome, 'to', output_pos_path)
    # !mv "{pos_genomes_path}"/"{genome}"* "{output_pos_path}"
    
#generate dataframe containing all tp-genomes and all the tp-genes contained in it
filtered_pos_df = pos_df[pos_df['assembly'].isin(selected_tp_genomes)]
remaining_pos_df = pos_df[~pos_df['assembly'].isin(selected_tp_genomes)]

#isolate all the headers and transfer them to the selected_tp_genes file
full_header_list = []
for i in range(0,len(filtered_pos_df)):
    full_header=str('>')+filtered_pos_df.iloc[i,1]+str('_')+filtered_pos_df.iloc[i,3]+str('_')+filtered_pos_df.iloc[i,5]
    full_header_list.append(full_header)

# generate fasta file with selected tp genes found in the selected genomes
print('generating selected_tp_genes.fasta')
with open(BGC_path+'/'+'report_2_generate_tp.txt', 'a') as f:
    f.write('\nselected_tp_genes in positive genomes are:\n')
tp_gene_counter=0
with open(BGC_path+'/'+BGC_type+'_tp_genes.fasta') as fh:
    lines=fh.readlines()
    for i in range(0,len(lines)):
        for j in range(0,len(full_header_list)):
            if full_header_list[j] in lines[i]:
                tp_gene_counter+=1
                with open(BGC_path+'/'+'report_2_generate_tp.txt', 'a') as f:
                    f.write(lines[i][1:-1]+'\n')
                with open(BGC_path+'/'+BGC_type+'_selected_tp_genes.fasta', 'a') as outfile:
                    outfile.write(lines[i]+lines[i+1])    
with open(BGC_path+'/'+'report_2_generate_tp.txt', 'a') as f:
    f.write('\n'+str(len(selected_tp_genomes))+' unique genomes with '+ str(tp_gene_counter)+' unique tp genes.\n\n')
                    
                    
# transfer all amino acid sequences that are not part of the tp-genomes to a fasta file
print('generating selected_tp_aa.fasta')
with open(BGC_path+'/'+'report_2_generate_tp.txt', 'a') as f:
    f.write('\nselected_tp_aa sequences for muscle alignment are:\n')
tp_aa_counter = 0
with open(BGC_path+'/'+BGC_type+'_selected_tp_aa.fasta', 'a') as outfile:
    for i in range(0,len(remaining_pos_df)):
        tp_aa_counter+=1
        fasta_header=str('>')+remaining_pos_df.iloc[i,1]+str('_')+remaining_pos_df.iloc[i,3]+str('_')+remaining_pos_df.iloc[i,5]+'\n'
        sequence = remaining_pos_df.iloc[i,6][2:-2]+'\n'
        with open(BGC_path+'/'+'report_2_generate_tp.txt', 'a') as f:
            f.write(fasta_header[1:-1]+'\n')
        outfile.write(fasta_header)
        outfile.write(sequence)
with open(BGC_path+'/'+'report_2_generate_tp.txt', 'a') as f:
    f.write('\n'+str(len(remaining_pos_genomes))+' unique genomes with '+ str(tp_aa_counter)+' unique aa sequences.\n\n')

    
print('Done')
# Out:
# moving positive GCF_009363655.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/pos_genomes
# moving positive GCF_009363735.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/pos_genomes
# moving positive GCF_013085545.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/pos_genomes
# moving positive GCF_012317585.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/pos_genomes
# moving positive GCF_014490785.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/pos_genomes
# moving positive GCF_009649995.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/pos_genomes
# moving positive GCF_004328865.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/pos_genomes
# moving positive GCF_002009335.2 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/pos_genomes
# moving positive GCF_000217795.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/pos_genomes
# moving positive GCF_015265455.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/pos_genomes
# generating selected_tp_genes.fasta
# generating selected_tp_aa.fasta
# Done

# %%
#Move selected neg genome files to different location
unique_neg_df = neg_df.drop_duplicates(subset='assembly', inplace=False)
# gets a list of length of specified amount of neg genomes
neg_genomes_list = list(unique_neg_df.iloc[:,1])

with open(BGC_path+'/'+'report_2_generate_tp.txt', 'a') as f:
    f.write('\n'+'Using blastn to check negative genomes for contamination'+'\n\n')

# makes blast databases of all individual neg genomes (easier to keep track of accession numbers than when combining)
for genomes in neg_genomes_list:
    # !makeblastdb -in "{neg_genomes_path}"/"{genomes}"* -dbtype nucl -out "{neg_blast_db_path}"/"{genomes}"_db

# runs blastn search of all TP genes against all blast databases of negative genomes
for genomes in neg_genomes_list:
    # !blastn -db "{neg_blast_db_path}"/"{genomes}"_db -query "{BGC_path}"/"{BGC_type}"_selected_tp_genes.fasta -out "{neg_blast_results_path}"/"{genomes}".blastout -outfmt "6 qseqid sseqid pident evalue"

# use pandas to concatenate all blast output tables
df_list = []
for outfile in os.listdir(neg_blast_results_path):
    try:
        blast_df = pd.read_csv(neg_blast_results_path+'/'+outfile, sep='\t', names=['qseqid', 'sseqid', 'pident', 'evalue'], index_col=None)
        blast_df['subject_accession'] = '.'.join(outfile.split('.')[0:2])
        df_list.append(blast_df)
    except EmptyDataError:
        continue
        
# Generate a list of contaminated negative genomes        
remove_df = pd.concat(df_list)
remove_list = list(remove_df.iloc[:,4])

with open(BGC_path+'/'+'report_2_generate_tp.txt', 'a') as f:
    f.write('\n'+'Contamination with tp_seqs:\n'+str(list(remove_df.iloc[:,0]))+'\nsequences identified in negative samples:\n'+str(remove_list)+'\n\n')

# Remove these contaminated samples from the possible pool of negative sequences
cleaned = ~unique_neg_df['assembly'].isin(remove_list)
cleaned_unique_neg_df = unique_neg_df[cleaned]

# Select a preset number of negative genomes (this could lead to fewer genomes available than selected. Handle)
selected_neg_genomes = list(cleaned_unique_neg_df.iloc[:,1])[0:select_neg_genomes]

# report block
with open(BGC_path+'/'+'report_2_generate_tp.txt', 'a') as f:
    f.write('\nselected_neg_genomes are:\n')
    f.write(str(selected_neg_genomes))

for genome in selected_neg_genomes:
    print('moving negative', genome, 'to', output_neg_path)
    # !mv "{neg_genomes_path}"/"{genome}"* "{output_neg_path}"

print('Done')
# Out:
# Building a new DB, current time: 07/20/2021 10:57:53
# New DB name:   /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_blast/databases/GCF_002094855.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/YcaO/base_genomes/temp_neg_genomes/GCF_002094855.1_ASM209485v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 89 sequences in 0.105674 seconds.
#
#
# Building a new DB, current time: 07/20/2021 10:57:53
# New DB name:   /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_blast/databases/GCF_009664145.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/YcaO/base_genomes/temp_neg_genomes/GCF_009664145.1_ASM966414v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 1 sequences in 0.039063 seconds.
#
#
# Building a new DB, current time: 07/20/2021 10:57:54
# New DB name:   /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_blast/databases/GCF_001316435.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/YcaO/base_genomes/temp_neg_genomes/GCF_001316435.1_ASM131643v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 52 sequences in 0.02495 seconds.
#
#
# Building a new DB, current time: 07/20/2021 10:57:54
# New DB name:   /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_blast/databases/GCF_013283165.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/YcaO/base_genomes/temp_neg_genomes/GCF_013283165.1_ASM1328316v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 20 sequences in 0.0475881 seconds.
#
#
# Building a new DB, current time: 07/20/2021 10:57:54
# New DB name:   /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_blast/databases/GCF_013283445.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/YcaO/base_genomes/temp_neg_genomes/GCF_013283445.1_ASM1328344v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 22 sequences in 0.0431218 seconds.
#
#
# Building a new DB, current time: 07/20/2021 10:57:54
# New DB name:   /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_blast/databases/GCF_009363475.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/YcaO/base_genomes/temp_neg_genomes/GCF_009363475.1_ASM936347v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 1 sequences in 0.0578671 seconds.
#
#
# Building a new DB, current time: 07/20/2021 10:57:55
# New DB name:   /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_blast/databases/GCF_004354305.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/YcaO/base_genomes/temp_neg_genomes/GCF_004354305.1_ASM435430v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 1 sequences in 0.0576019 seconds.
#
#
# Building a new DB, current time: 07/20/2021 10:57:55
# New DB name:   /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_blast/databases/GCF_004022445.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/YcaO/base_genomes/temp_neg_genomes/GCF_004022445.1_ASM402244v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 222 sequences in 0.0914261 seconds.
#
#
# Building a new DB, current time: 07/20/2021 10:57:55
# New DB name:   /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_blast/databases/GCF_003584015.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/YcaO/base_genomes/temp_neg_genomes/GCF_003584015.1_ASM358401v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 146 sequences in 0.094363 seconds.
#
#
# Building a new DB, current time: 07/20/2021 10:57:55
# New DB name:   /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_blast/databases/GCF_001434745.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/YcaO/base_genomes/temp_neg_genomes/GCF_001434745.1_ASM143474v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 46 sequences in 0.032867 seconds.
#
#
# Building a new DB, current time: 07/20/2021 10:57:56
# New DB name:   /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_blast/databases/GCF_002026065.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/YcaO/base_genomes/temp_neg_genomes/GCF_002026065.1_ASM202606v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 358 sequences in 0.0251532 seconds.
#
#
# Building a new DB, current time: 07/20/2021 10:57:56
# New DB name:   /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_blast/databases/GCF_902728235.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/YcaO/base_genomes/temp_neg_genomes/GCF_902728235.1_LCC4_PacBio_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 2 sequences in 0.070595 seconds.
#
#
# Building a new DB, current time: 07/20/2021 10:57:56
# New DB name:   /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_blast/databases/GCF_002864685.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/YcaO/base_genomes/temp_neg_genomes/GCF_002864685.1_ASM286468v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 93 sequences in 0.088073 seconds.
#
#
# Building a new DB, current time: 07/20/2021 10:57:56
# New DB name:   /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_blast/databases/GCF_014596975.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/YcaO/base_genomes/temp_neg_genomes/GCF_014596975.1_ASM1459697v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 119 sequences in 0.04601 seconds.
#
#
# Building a new DB, current time: 07/20/2021 10:57:57
# New DB name:   /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_blast/databases/GCF_001681975.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/YcaO/base_genomes/temp_neg_genomes/GCF_001681975.1_ASM168197v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 65 sequences in 0.04617 seconds.
#
#
# Building a new DB, current time: 07/20/2021 10:57:57
# New DB name:   /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_blast/databases/GCF_001273715.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/YcaO/base_genomes/temp_neg_genomes/GCF_001273715.1_ASM127371v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 55 sequences in 0.048228 seconds.
#
#
# Building a new DB, current time: 07/20/2021 10:57:57
# New DB name:   /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_blast/databases/GCF_004123195.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/YcaO/base_genomes/temp_neg_genomes/GCF_004123195.1_ASM412319v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 87 sequences in 0.0558228 seconds.
#
#
# Building a new DB, current time: 07/20/2021 10:57:57
# New DB name:   /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_blast/databases/GCF_001939735.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/YcaO/base_genomes/temp_neg_genomes/GCF_001939735.1_ASM193973v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 101 sequences in 0.0784199 seconds.
#
#
# Building a new DB, current time: 07/20/2021 10:57:57
# New DB name:   /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_blast/databases/GCF_014694465.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/YcaO/base_genomes/temp_neg_genomes/GCF_014694465.1_ASM1469446v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 215 sequences in 0.0728061 seconds.
#
#
# Building a new DB, current time: 07/20/2021 10:57:58
# New DB name:   /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_blast/databases/GCF_000452905.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/YcaO/base_genomes/temp_neg_genomes/GCF_000452905.1_CC1544_092313_2.0_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 376 sequences in 0.131297 seconds.
#
#
# Building a new DB, current time: 07/20/2021 10:57:58
# New DB name:   /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_blast/databases/GCF_009910325.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/YcaO/base_genomes/temp_neg_genomes/GCF_009910325.1_ASM991032v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 67 sequences in 0.0560842 seconds.
#
#
# Building a new DB, current time: 07/20/2021 10:57:58
# New DB name:   /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_blast/databases/GCF_002806945.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/YcaO/base_genomes/temp_neg_genomes/GCF_002806945.1_ASM280694v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 30 sequences in 0.0383899 seconds.
#
#
# Building a new DB, current time: 07/20/2021 10:57:58
# New DB name:   /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_blast/databases/GCF_009712075.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/YcaO/base_genomes/temp_neg_genomes/GCF_009712075.1_ASM971207v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 33 sequences in 0.0612109 seconds.
#
#
# Building a new DB, current time: 07/20/2021 10:57:59
# New DB name:   /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_blast/databases/GCF_003025005.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/YcaO/base_genomes/temp_neg_genomes/GCF_003025005.1_ASM302500v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 89 sequences in 0.090857 seconds.
#
#
# Building a new DB, current time: 07/20/2021 10:57:59
# New DB name:   /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_blast/databases/GCF_001295965.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/YcaO/base_genomes/temp_neg_genomes/GCF_001295965.1_ASM129596v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 51 sequences in 0.0421939 seconds.
#
#
# Building a new DB, current time: 07/20/2021 10:57:59
# New DB name:   /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_blast/databases/GCF_016919725.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/YcaO/base_genomes/temp_neg_genomes/GCF_016919725.1_ASM1691972v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 1 sequences in 0.0520151 seconds.
#
#
# Building a new DB, current time: 07/20/2021 10:58:00
# New DB name:   /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_blast/databases/GCF_013112375.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/YcaO/base_genomes/temp_neg_genomes/GCF_013112375.1_ASM1311237v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 2 sequences in 0.0652251 seconds.
#
#
# Building a new DB, current time: 07/20/2021 10:58:00
# New DB name:   /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_blast/databases/GCF_004358035.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/YcaO/base_genomes/temp_neg_genomes/GCF_004358035.1_ASM435803v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 37 sequences in 0.0429239 seconds.
#
#
# Building a new DB, current time: 07/20/2021 10:58:00
# New DB name:   /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_blast/databases/GCF_003258595.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/YcaO/base_genomes/temp_neg_genomes/GCF_003258595.1_ASM325859v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 44 sequences in 0.08586 seconds.
#
#
# Building a new DB, current time: 07/20/2021 10:58:00
# New DB name:   /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_blast/databases/GCF_012395805.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/YcaO/base_genomes/temp_neg_genomes/GCF_012395805.1_ASM1239580v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 29 sequences in 0.0555959 seconds.
#
#
# Building a new DB, current time: 07/20/2021 10:58:01
# New DB name:   /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_blast/databases/GCF_015245355.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/YcaO/base_genomes/temp_neg_genomes/GCF_015245355.1_ASM1524535v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 1 sequences in 0.05442 seconds.
#
#
# Building a new DB, current time: 07/20/2021 10:58:01
# New DB name:   /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_blast/databases/GCF_000830495.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/YcaO/base_genomes/temp_neg_genomes/GCF_000830495.1_ASM83049v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 24 sequences in 0.054806 seconds.
#
#
# Building a new DB, current time: 07/20/2021 10:58:01
# New DB name:   /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_blast/databases/GCF_001974605.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/YcaO/base_genomes/temp_neg_genomes/GCF_001974605.1_ASM197460v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 40 sequences in 0.07622 seconds.
#
#
# Building a new DB, current time: 07/20/2021 10:58:01
# New DB name:   /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_blast/databases/GCF_002556635.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/YcaO/base_genomes/temp_neg_genomes/GCF_002556635.1_ASM255663v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 57 sequences in 0.0476329 seconds.
#
#
# Building a new DB, current time: 07/20/2021 10:58:01
# New DB name:   /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_blast/databases/GCF
# New DB name:   /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_blast/databases/GCF_902209435.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/YcaO/base_genomes/temp_neg_genomes/GCF_902209435.1_Katie-F-Assembly-1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 43 sequences in 0.037811 seconds.
#
#
# Building a new DB, current time: 07/20/2021 11:00:49
# New DB name:   /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_blast/databases/GCF_002153975.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/YcaO/base_genomes/temp_neg_genomes/GCF_002153975.1_ASM215397v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 169 sequences in 0.102479 seconds.
#
#
# Building a new DB, current time: 07/20/2021 11:00:50
# New DB name:   /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_blast/databases/GCF_006371625.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/YcaO/base_genomes/temp_neg_genomes/GCF_006371625.1_ASM637162v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 139 sequences in 0.0908189 seconds.
#
#
# Building a new DB, current time: 07/20/2021 11:00:50
# New DB name:   /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_blast/databases/GCF_002953115.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/YcaO/base_genomes/temp_neg_genomes/GCF_002953115.1_ASM295311v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 2 sequences in 0.0782611 seconds.
#
#
# Building a new DB, current time: 07/20/2021 11:00:50
# New DB name:   /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_blast/databases/GCF_002976495.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/YcaO/base_genomes/temp_neg_genomes/GCF_002976495.1_ASM297649v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 101 sequences in 0.050967 seconds.
# moving negative GCF_002094855.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_009664145.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_001316435.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_013283165.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_013283445.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_009363475.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_004354305.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_004022445.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_003584015.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_001434745.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_002026065.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_902728235.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_002864685.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_014596975.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_001681975.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_001273715.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_004123195.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_001939735.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_014694465.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_000452905.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_009910325.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_002806945.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_009712075.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_003025005.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_001295965.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_016919725.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_013112375.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_004358035.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_003258595.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_012395805.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_015245355.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_000830495.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_001974605.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_002556635.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_004803475.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_000468615.2 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_001292705.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_001636545.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_003003795.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_011601345.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_003429285.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_013342145.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_016605985.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_010279875.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_000661915.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_001238295.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_001558055.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_003315815.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_000334195.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_003075525.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_001854065.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_002879635.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_001942405.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_002737765.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_003721245.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_014858715.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_005040135.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_014837295.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_003597125.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_000286315.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_003839475.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_003063245.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_003199425.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_003258515.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_000235975.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_018128865.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_002149105.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_000333835.2 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_009184905.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_016595365.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_011392125.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_001495115.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_006543045.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_900166205.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_002326665.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_007858255.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_006379685.2 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_003069345.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_015461845.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_000979635.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_016814205.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_003815655.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_009756665.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_003145625.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_017351515.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_002882155.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_003382855.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_003349265.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_000490355.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_003197505.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_017350015.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_010093095.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_016770915.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_016595265.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_003295565.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_004337335.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_000931385.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_009177065.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_000812065.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_001189955.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_001710555.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_003382935.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_003298775.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_003730315.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_001876575.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_001183865.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_014855745.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_900163915.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_000475315.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_003067945.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_003198295.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_016603675.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_011378905.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_003069325.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_000736325.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_015276765.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_003068065.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_000746665.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_011299615.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_003959545.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_003931575.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_002901605.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_000186145.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_001310575.2 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_006374995.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_005508865.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_017743775.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_003294075.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_002808305.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_006371405.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_900382745.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_900166185.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_000473245.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_015207265.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_014698755.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_016603195.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_014180685.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_017255225.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_006802945.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# moving negative GCF_013048515.1 to /media/manu/RiPP_Prioritiser/YcaO/base_genomes/neg_genomes
# Done

# %% [markdown]
# The cell below generates a muscle alignment of the protein sequences from genomes that were not chosen as pos_genomes. However, in order to follow the procedure of the 2019 Sugimoto paper more closely, instead download the seed alignment for the respective protein of interest from pfam in fasta format and save is as {BGC_type}_selected_tp_alignment.fasta

# %%
#!module load MUSCLE/3.8.1551
#not sure why full path is required?
#with open(BGC_path+'/'+'report_2_generate_tp.txt', 'a') as f:
#    f.write('\n\nMUSCLE alignment details:\n')

#!muscle -in "{BGC_path}"/"{BGC_type}"_selected_tp_aa.fasta -out "{BGC_path}"/"{BGC_type}"_selected_tp_alignment.fasta -loga "{BGC_path}"/report_2_generate_tp.txt
#!module unload MUSCLE/3.8.1551

# %% [markdown]
# Introduce a step here where all negative genomes are concatenated, a blastdb is built from the concatenated file, and all selected TP genes are used to query the blast db. If there are any hits, remove that sequence from the selected_neg_genomes_list, and add another one, then check again.
