# %% [markdown]
# In addition to the original script, 2_generate_TP, this script does a blast search of selected_tp_genes against temp_neg_genomes and filters out all genomes that have a hit. In addition to 2.1_generate_TP, this script also does an hmm search, using an alignment of selected_tp_genes as query against negative genomes. It combines results of blast and hmm searches and removes all samples with hits from the pool of neg_genomes to choose from. One further parameter is required to specify an hmm evalue cutoff for samples to remove. Ideally, this would be 0, but I decided to keep a cutoff, as the original negative genomes from the sugimoto paper also have positive hits for an oxyN hmm.
#
#
# This script generates the 2 remaining files required for input:
# - True positive genes (nucleotide fasta)
# - protein alignment (amino acid fasta)
# IMPORTANTLY, these 2 files are created from non-overlapping sequences!
#
#
# And also moves the corresponding files to new directories so that coverage tables can be generated from them.
#
# In the first cell specify:
# - BGC type (This name must stay constant throughout the scripts)
# - select_neg_genomes, i.e. the amount of negative genomes to be transferred to the neg_genomes directory
# - select_pos_genomes, i.e. the amount of positive genomes to be transferred to the pos_genomes directory and to generate the tp_genes file from (the surplus amount will be used to generate the protein alignment from)
# - pos_isolation_source_filter, if these terms are found in the isolation_source column of the positive samples in the summary file, they will be scored higher in a scoring column, i.e. samples from a known and desired isolation source will be used preferentially.
# - neg_isolation_source_filter, accordingly
# - avoid_list. These terms are scored with a 0, end at the bottom of the table, and will be picked last. This is useful when an uncommon gene is searched for and more, and/or more tenuous isolation sources have been allowed during download. These are generally words that contain one of the search terms, e.g. 'sea' in 'diseased'.

# %% [markdown]
# Modify in such a way that TP genes are used as query against all individual negative genomes. Negative genomes are only moved from temp directory to neg_genomes directory if the blast search comes back negative

# %%
BGC_type = 'RTX_toxin_acyltransferase'
select_neg_genomes = 140
select_pos_genomes = 10
hmm_evalue_cutoff = 3

avoid_list = ['', 'isolation_source not annotated', 'diseased', 'mice', 'spice', 'septicemic', 'research', 'crevice']
#these are identical to first script, but don't have to be
pos_isolation_source_filter =  ['marine', 'sea', 'sponge', 'ocean', 'porifera', 'seafloor','sediment', 'water', 'tidal', 'coral', 'reef', 'coast', 'ship', 'fish', 'aquaculture', 'atlantic', 'pacific', 'mediterranean', 'baltic', 'pond', 'river', 'ice', 'carribean', 'lake', 'fjord', 'marina', 'hydro', 'algal', 'algae', 'clam', 'shell', 'mussel']
neg_isolation_source_filter = ['marine', 'sea', 'sponge', 'ocean', 'porifera', 'seafloor', 'sediment', 'water', 'tidal', 'coral', 'reef', 'coast', 'ship', 'fish', 'aquaculture', 'atlantic', 'pacific', 'mediterranean', 'baltic', 'pond', 'river', 'ice', 'carribean', 'lake', 'fjord', 'marina', 'hydro', 'algal', 'algae', 'clam', 'shell', 'mussel']

# %%
import os
from os import listdir, mkdir
from os.path import isfile, join
from pathlib import Path
import pandas as pd
from pandas.errors import EmptyDataError
import warnings

# %%
def makedir(dirpath):
    if os.path.isdir(dirpath):
        print(dirpath,'exists already')
    else:
        print('Making', dirpath)    
        os.mkdir(dirpath)

        
# Defining paths for required directory structure for input and output files relative to parent directory
#parent_dir='/media/manu/RiPP_Prioritiser/'
#will make directories relative to the path the notebook was opened in
parent_dir= !echo $(pwd)
BGC_path=os.path.join(parent_dir[0], BGC_type)
neg_genomes_path=os.path.join(BGC_path, 'base_genomes/temp_neg_genomes')
pos_genomes_path=os.path.join(BGC_path, 'base_genomes/temp_pos_genomes')
output_neg_path=os.path.join(BGC_path, 'base_genomes/neg_genomes')
output_pos_path=os.path.join(BGC_path, 'base_genomes/pos_genomes')
#qc-paths.
quality_control_path=os.path.join(BGC_path, 'base_genomes/quality_control')
neg_blast_path=os.path.join(quality_control_path, 'neg_blast')
neg_blast_db_path=os.path.join(neg_blast_path, 'databases')
neg_blast_results_path=os.path.join(neg_blast_path, 'outfiles')
pos_blast_path=os.path.join(quality_control_path, 'pos_blast')
pos_blast_db_path=os.path.join(pos_blast_path, 'databases')
pos_blast_results_path=os.path.join(pos_blast_path, 'results')
neg_hmm_path=os.path.join(quality_control_path, 'neg_hmm')
neg_hmm_db_path=os.path.join(neg_hmm_path, 'queries')
neg_hmm_results_path=os.path.join(neg_hmm_path, 'outfiles')
pos_hmm_path=os.path.join(quality_control_path, 'pos_hmm')
pos_hmm_db_path=os.path.join(pos_hmm_path, 'databases')
pos_hmm_results_path=os.path.join(pos_hmm_path, 'results')

# made directories manually. remove or comment after running.
#validation_pos_genomes_path=os.path.join(BGC_path, 'base_genomes/validation_pos_genomes')
#validation_coverage_table_path=os.path.join(BGC_path, 'validation_coverage_tables')

# Calling function to make directories if they don't exist yet
makedir(output_neg_path)
makedir(output_pos_path)
makedir(quality_control_path)
makedir(neg_blast_path)
makedir(neg_blast_db_path)
makedir(neg_blast_results_path)
makedir(pos_blast_path)
makedir(pos_blast_db_path)
makedir(pos_blast_results_path)
makedir(neg_hmm_path)
makedir(neg_hmm_db_path)
makedir(neg_hmm_results_path)
makedir(pos_hmm_path)
makedir(pos_hmm_db_path)
makedir(pos_hmm_results_path)

#makedir(validation_pos_genomes_path)

os.chdir(BGC_path)
# Out:
# Making /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/neg_genomes
# Making /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/pos_genomes
# Making /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control
# Making /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast
# Making /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases
# Making /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/outfiles
# Making /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/pos_blast
# Making /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/pos_blast/databases
# Making /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/pos_blast/results
# Making /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_hmm
# Making /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_hmm/queries
# Making /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_hmm/outfiles
# Making /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/pos_hmm
# Making /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/pos_hmm/databases
# Making /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/pos_hmm/results

# %%
# Generating a report file for this script
with open(BGC_path+'/'+'report_2_generate_tp.txt', 'w') as f:
    f.write('Output directory is: '+BGC_path+'\n')
    f.write('\nBGC_type = '+BGC_type)
    f.write('\nselect_neg_genomes = '+str(select_neg_genomes))
    f.write('\nselect_pos_genomes = '+str(select_pos_genomes))
    f.write('\nhmm_evalue_cutoff = '+str(hmm_evalue_cutoff))
    f.write('\navoid_list = '+str(avoid_list))
    f.write('\nneg_isolation_source_filter = '+str(neg_isolation_source_filter))
    f.write('\npos_isolation_source_filter = '+str(pos_isolation_source_filter)+'\n')

# %%
# load summary table into data frame () output from 1.)
summary_file = pd.read_csv('summary.tsv', sep='\t')

# %% [markdown]
# Change order of tables to prioritize samples that have an isolation source

# %%
warnings.filterwarnings('ignore')

#filter positives and drop all duplicate protein sequences originating from different organisms
pos_mask = (summary_file['dir'] == '+')
pos_df = summary_file[pos_mask]
pos_df.drop_duplicates(subset='protein_id', keep=False, inplace=True)


#filter negatives
neg_mask = (summary_file['dir'] == '-')
neg_df = summary_file[neg_mask]

#scoring words in isolation source so as to preferentially pick samples with chosen isolation sources

def custom_sorting(source,isolation_source_filter):
    score = 1
    if isolation_source_filter=='pos':
        for word in pos_isolation_source_filter:
            if word in source:
                score +=1
        for word in avoid_list:
            if source == word:
                score=0
    elif isolation_source_filter=='neg':
        for word in neg_isolation_source_filter:
            if word in source:
                score +=1
        for word in avoid_list:
            if source == word:
                score=0
    return score


pos_df['scoring_column'] = pos_df.apply(lambda x: custom_sorting(x['isolation_source'],'pos'),axis=1)
neg_df['scoring_column'] = neg_df.apply(lambda x: custom_sorting(x['isolation_source'],'neg'),axis=1)

pos_df.sort_values(by=['scoring_column'], axis=0, ascending=False, inplace=True)
neg_df.sort_values(by=['scoring_column'], axis=0, ascending=False, inplace=True)

# %%
#Split positive genomes into 2 bins, one goes towards tp-genes and is the pos-genomes used for synthesising metagenomes
#the other one constitutes a source of protein sequences for alignment as an input file
#(removed the latter functionality and used pfam alignments of the protein instead)

# Genomes selected in such a way that they are from the top of the pre-sorted pos_df
unique_pos_df = pos_df.drop_duplicates(subset='assembly', inplace=False)
selected_tp_genomes = list(unique_pos_df.iloc[:,1])[0:select_pos_genomes]
remaining_pos_genomes = list(unique_pos_df.iloc[:,1])[select_pos_genomes:]

with open(BGC_path+'/'+'report_2_generate_tp.txt', 'a') as f:
    f.write('\nselected_tp_genomes are:\n')
    f.write(str(selected_tp_genomes)+'\n')

#select genomes and isolate GCF number from them, move selected tp genomes to final pos_genomes directory
for genome in selected_tp_genomes:
    print('moving positive', genome, 'to', output_pos_path)
    # !mv "{pos_genomes_path}"/"{genome}"* "{output_pos_path}"
    
#generate dataframe containing all tp-genomes and all the tp-genes contained in it
filtered_pos_df = pos_df[pos_df['assembly'].isin(selected_tp_genomes)]
remaining_pos_df = pos_df[~pos_df['assembly'].isin(selected_tp_genomes)]

#isolate all the headers and transfer them to the selected_tp_genes file
full_header_list = []
for i in range(0,len(filtered_pos_df)):
    full_header=str('>')+filtered_pos_df.iloc[i,1]+str('_')+filtered_pos_df.iloc[i,3]+str('_')+filtered_pos_df.iloc[i,5]
    full_header_list.append(full_header)

# generate fasta file with selected tp genes found in the selected genomes
print('generating selected_tp_genes.fasta')
with open(BGC_path+'/'+'report_2_generate_tp.txt', 'a') as f:
    f.write('\nselected_tp_genes in positive genomes are:\n')
tp_gene_counter=0
with open(BGC_path+'/'+BGC_type+'_tp_genes.fasta') as fh:
    lines=fh.readlines()
    for i in range(0,len(lines)):
        for j in range(0,len(full_header_list)):
            if full_header_list[j] in lines[i]:
                tp_gene_counter+=1
                with open(BGC_path+'/'+'report_2_generate_tp.txt', 'a') as f:
                    f.write(lines[i][1:-1]+'\n')
                with open(BGC_path+'/'+BGC_type+'_selected_tp_genes.fasta', 'a') as outfile:
                    outfile.write(lines[i]+lines[i+1])    
with open(BGC_path+'/'+'report_2_generate_tp.txt', 'a') as f:
    f.write('\n'+str(len(selected_tp_genomes))+' unique genomes with '+ str(tp_gene_counter)+' unique tp genes.\n\n')
                    
                    
# transfer all amino acid sequences that are not part of the tp-genomes to a fasta file
print('generating selected_tp_aa.fasta')
with open(BGC_path+'/'+'report_2_generate_tp.txt', 'a') as f:
    f.write('\nsremaining samples are:\n')
tp_aa_counter = 0
with open(BGC_path+'/'+BGC_type+'_selected_tp_aa.fasta', 'a') as outfile:
    for i in range(0,len(remaining_pos_df)):
        tp_aa_counter+=1
        fasta_header=str('>')+remaining_pos_df.iloc[i,1]+str('_')+remaining_pos_df.iloc[i,3]+str('_')+remaining_pos_df.iloc[i,5]+'\n'
        sequence = remaining_pos_df.iloc[i,6][2:-2]+'\n'
        with open(BGC_path+'/'+'report_2_generate_tp.txt', 'a') as f:
            f.write(fasta_header[1:-1]+'\n')
        outfile.write(fasta_header)
        outfile.write(sequence)
with open(BGC_path+'/'+'report_2_generate_tp.txt', 'a') as f:
    f.write('\n'+str(len(remaining_pos_genomes))+' unique genomes with '+ str(tp_aa_counter)+' unique aa sequences.\n\n')

    
print('Done')
# Out:
# moving positive GCF_013357885.1 to /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/pos_genomes
# moving positive GCF_002119525.1 to /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/pos_genomes
# moving positive GCF_000307145.1 to /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/pos_genomes
# moving positive GCF_013357825.1 to /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/pos_genomes
# moving positive GCF_008369605.1 to /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/pos_genomes
# generating selected_tp_genes.fasta
# generating selected_tp_aa.fasta
# Done

# %%
# move 10 more pos_genomes to validation_pos_genomes
#unique_pos_df = pos_df.drop_duplicates(subset='assembly', inplace=False)
#selected_tp_genomes = list(unique_pos_df.iloc[:,1])[0:select_pos_genomes]
#validation_tp_genomes=list(unique_pos_df.iloc[:,1])[select_pos_genomes:select_pos_genomes+10]

#select genomes and isolate GCF number from them, move selected tp genomes to final pos_genomes directory
#for genome in validation_tp_genomes:
#    print('moving positive', genome, 'to', validation_pos_genomes_path)
#    !mv "{pos_genomes_path}"/"{genome}"* "{validation_pos_genomes_path}"

# %%
# To confirm, run blast on all samples selected as validation pos genomes

# makes blast databases of all individual neg genomes (easier to keep track of accession numbers than when combining)
#for genomes in validation_tp_genomes:
#    !makeblastdb -in "{validation_tp_genomes}"/"{genomes}"* -dbtype nucl -out "{pos_blast_db_path}"/"{genomes}"_db

#for genomes in selected_tp_genomes:
#    !blastn -db "{pos_blast_db_path}"/"{genomes}"_db -query "{BGC_path}"/"{BGC_type}"_selected_tp_genes.fasta -out "{pos_blast_results_path}"/"{genomes}".blastout -outfmt "6 qseqid sseqid pident evalue length"
    
# use pandas to concatenate all blast output tables
#df_list = []
#for outfile in os.listdir(pos_blast_results_path):
#    try:
#        blast_df = pd.read_csv(pos_blast_results_path+'/'+outfile, sep='\t', names=['qseqid', 'sseqid', 'pident', 'evalue', 'length'], index_col=None)
#        blast_df['sample'] = '.'.join(outfile.split('.')[0:2])
#        df_list.append(blast_df)
#    except EmptyDataError:
#        continue
        
# Generate a list of contaminated negative genomes        
#pos_blast_hits_df = pd.concat(df_list)
#pos_blast_hits_df.to_csv(pos_blast_path+'/blast_results_summary.csv', index=False)

# %%
#Use blast to find tp_gene contamination in negative samples
unique_neg_df = neg_df.drop_duplicates(subset='assembly', inplace=False)
# gets a list of length of specified amount of neg genomes
neg_genomes_list = list(unique_neg_df.iloc[:,1])

with open(BGC_path+'/'+'report_2_generate_tp.txt', 'a') as f:
    f.write('\n'+'Using blastn to check negative genomes for contamination'+'\n')

# makes blast databases of all individual neg genomes (easier to keep track of accession numbers than when combining)
for genomes in neg_genomes_list:
    # !makeblastdb -in "{neg_genomes_path}"/"{genomes}"* -dbtype nucl -out "{neg_blast_db_path}"/"{genomes}"_db

# runs blastn search of all TP genes against all blast databases of negative genomes
# even if no alteration is made to the original tp_genes file, rengame it to fit the path in the command below, accordingly.
for genomes in neg_genomes_list:
    # !blastn -db "{neg_blast_db_path}"/"{genomes}"_db -query "{BGC_path}"/"{BGC_type}"_selected_tp_genes_altered.fasta -out "{neg_blast_results_path}"/"{genomes}".blastout -outfmt "6 qseqid sseqid pident evalue length"

# use pandas to concatenate all blast output tables
df_list = []
for outfile in os.listdir(neg_blast_results_path):
    try:
        blast_df = pd.read_csv(neg_blast_results_path+'/'+outfile, sep='\t', names=['qseqid', 'sseqid', 'pident', 'evalue', 'length'], index_col=None)
        blast_df['sample'] = '.'.join(outfile.split('.')[0:2])
        df_list.append(blast_df)
    except EmptyDataError:
        continue
        
# Generate a list of contaminated negative genomes        
remove_df = pd.concat(df_list)
remove_df.to_csv(quality_control_path+'/blast_fn_samples.csv', index=False)
unique_remove_df = remove_df.drop_duplicates(subset='sample', inplace=False)
blast_remove_list = list(unique_remove_df.iloc[:,4])

with open(BGC_path+'/'+'report_2_generate_tp.txt', 'a') as f:
    f.write('\n'+'Contamination with tp_seqs:\n'+str(list(remove_df.iloc[:,0]))+'\nsequences identified in negative samples:\n'+str(blast_remove_list)+'\n\n')

print('Done')
# Out:
# Building a new DB, current time: 11/09/2021 11:19:36
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_003075095.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_003075095.1_ASM307509v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 87 sequences in 0.327964 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:19:36
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_013282925.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_013282925.1_ASM1328292v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 21 sequences in 0.161026 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:19:37
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_004792475.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_004792475.1_ASM479247v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 1 sequences in 0.122471 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:19:37
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_019266105.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_019266105.1_ASM1926610v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 64 sequences in 0.133247 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:19:37
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_013283055.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_013283055.1_ASM1328305v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 22 sequences in 0.0771489 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:19:38
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_014705705.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_014705705.1_ASM1470570v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 45 sequences in 0.0820701 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:19:38
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_002835465.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_002835465.1_ASM283546v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 32 sequences in 0.129622 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:19:38
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_005862235.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_005862235.1_ASM586223v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 11 sequences in 0.132303 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:19:39
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_000297635.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_000297635.1_ASM29763v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 57 sequences in 0.147806 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:19:39
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_001529365.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_001529365.1_ASM152936v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 100 sequences in 0.133367 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:19:39
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_018224955.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_018224955.1_ASM1822495v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 22 sequences in 0.144173 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:19:40
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_007954355.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_007954355.1_ASM795435v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 100 sequences in 0.129798 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:19:40
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_009363435.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_009363435.1_ASM936343v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 1 sequences in 0.169744 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:19:40
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_004121115.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_004121115.1_ASM412111v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 46 sequences in 0.149946 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:19:41
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_013283095.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_013283095.1_ASM1328309v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 33 sequences in 0.0936739 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:19:41
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_011045095.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_011045095.1_ASM1104509v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 83 sequences in 0.147019 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:19:41
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_002964545.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_002964545.1_ASM296454v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 51 sequences in 0.240409 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:19:42
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_017255015.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_017255015.1_ASM1725501v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 922 sequences in 0.177863 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:19:42
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_003797885.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_003797885.1_ASM379788v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 45 sequences in 0.138212 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:19:42
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_003975335.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_003975335.1_ASM397533v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 42 sequences in 0.178809 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:19:43
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_000737165.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_000737165.1_ASM73716v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 75 sequences in 0.093205 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:19:43
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_001975705.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_001975705.1_ASM197570v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 9 sequences in 0.212078 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:19:44
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_013387475.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_013387475.1_ASM1338747v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 28 sequences in 0.062634 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:19:44
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_014705715.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_014705715.1_ASM1470571v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 4 sequences in 0.102376 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:19:44
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_009363375.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_009363375.1_ASM936337v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 5 sequences in 0.188586 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:19:44
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_002087335.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_002087335.1_ASM208733v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 135 sequences in 0.13981 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:19:45
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_000943565.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_000943565.1_ASM94356v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 52 sequences in 0.122166 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:19:45
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_001418705.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_001418705.1_ASM141870v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 252 sequences in 0.134644 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:19:45
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_004524025.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_004524025.1_ASM452402v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 130 sequences in 0.156878 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:19:46
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_005043345.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_005043345.1_ASM504334v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 135 sequences in 0.130217 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:19:46
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_000622285.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_000622285.1_ASM62228v2_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 11 sequences in 0.144777 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:19:46
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_005041175.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_005041175.1_ASM504117v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 125 sequences in 0.165494 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:19:47
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_002150505.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_002150505.1_ASM215050v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 54 sequences in 0.121445 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:19:47
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_019263715.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_019263715.1_ASM1926371v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 666 sequences in 0.336138 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:19:48
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_014534745.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_014534745.1_ASM1453474v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 183 sequences in 0.232113 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:19:48
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_004297185.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_004297185.1_ASM429718v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 22 sequences in 0.067265 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:19:48
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_900537165.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_900537165.1_ASM90053716v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 34 sequences in 0.171132 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:19:49
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_002786285.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_002786285.1_ASM278628v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 23 sequences in 0.121965 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:19:49
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_003856375.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_003856375.1_ASM385637v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 1 sequences in 0.127878 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:19:49
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_004022425.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_004022425.1_ASM402242v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 149 sequences in 0.141959 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:19:50
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_001723295.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_001723295.1_ASM172329v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 470 sequences in 0.122946 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:19:50
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_000754925.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_000754925.1_ASM75492v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 185 sequences in 0.124168 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:19:50
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_000331225.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_000331225.1_SanAAP62ver1.0_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 22 sequences in 0.0750401 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:19:51
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_009208775.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_009208775.1_ASM920877v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 30 sequences in 0.132474 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:19:51
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_014694405.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_014694405.1_ASM1469440v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 304 sequences in 0.153552 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:19:51
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_005924235.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_005924235.1_ASM592423v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 134 sequences in 0.157292 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:19:52
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_007786285.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_007786285.1_ASM778628v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 82 sequences in 0.148218 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:19:52
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_017347085.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_017347085.1_ASM1734708v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 51 sequences in 0.102485 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:19:52
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_017812035.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_017812035.1_ASM1781203v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 64 sequences in 0.091295 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:19:53
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_018882205.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_018882205.1_ASM1888220v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 6 sequences in 0.055809 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:19:53
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_003030385.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_003030385.1_ASM303038v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 1 sequences in 0.225476 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:19:53
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_002873755.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_002873755.1_ASM287375v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 51 sequences in 0.163049 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:19:54
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_001675165.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_001675165.1_ASM167516v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 79 sequences in 0.13565 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:19:54
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_001900795.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_001900795.1_ASM190079v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 4 sequences in 0.129736 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:19:54
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_002737765.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_002737765.1_ASM273776v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 406 sequences in 0.179132 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:19:55
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_004196115.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_004196115.1_ASM419611v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 147 sequences in 0.186126 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:19:55
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_003144035.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_003144035.1_ASM314403v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 37 sequences in 0.100954 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:19:55
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_009036385.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_009036385.1_ASM903638v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 3 sequences in 0.0547521 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:19:56
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_019278505.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_019278505.1_ASM1927850v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 1 sequences in 0.109862 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:19:56
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_014077245.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_014077245.1_ASM1407724v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 97 sequences in 0.131628 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:19:56
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_016583785.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_016583785.1_ASM1658378v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 247 sequences in 0.204056 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:19:57
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_002954425.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_002954425.1_ASM295442v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 4 sequences in 0.115606 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:19:57
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_001179865.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_001179865.1_CLC_assembled_contigs_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 95 sequences in 0.0207741 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:19:57
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_018141185.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_018141185.1_ASM1814118v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 1 sequences in 0.0555511 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:19:57
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_001441635.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_001441635.1_ASM144163v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 122 sequences in 0.168168 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:19:58
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_020406675.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_020406675.1_ASM2040667v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 82 sequences in 0.142945 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:19:58
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_009857495.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_009857495.1_ASM985749v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 82 sequences in 0.160926 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:19:58
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_003061505.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_003061505.1_ASM306150v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 154 sequences in 0.112857 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:19:59
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_020514115.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_020514115.1_ASM2051411v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 22 sequences in 0.052002 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:19:59
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_002156965.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_002156965.1_ASM215696v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 1 sequences in 0.0398219 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:19:59
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_003313245.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_003313245.1_ASM331324v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 62 sequences in 0.119366 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:19:59
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_008370345.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_008370345.1_ASM837034v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 149 sequences in 0.164984 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:20:00
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_000497995.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_000497995.1_TB25_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 458 sequences in 0.113337 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:20:00
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_002876165.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_002876165.1_ASM287616v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 169 sequences in 0.09989 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:20:00
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_001989455.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_001989455.1_ASM198945v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 1 sequences in 0.0574729 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:20:01
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_013166635.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_013166635.1_ASM1316663v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 318 sequences in 0.156303 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:20:01
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_001730155.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_001730155.1_ASM173015v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 119 sequences in 0.161688 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:20:01
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_003608595.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_003608595.1_ASM360859v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 13 sequences in 0.0853851 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:20:02
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_003990055.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_003990055.1_ASM399005v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 54 sequences in 0.0895641 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:20:02
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_002838765.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_002838765.1_ASM283876v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 1 sequences in 0.0701911 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:20:02
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_001151185.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_001151185.1_4821_8_8_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 58 sequences in 0.121974 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:20:02
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_014169935.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_014169935.1_ASM1416993v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 3 sequences in 0.116744 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:20:03
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_001027025.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_001027025.1_ASM102702v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 1 sequences in 0.061507 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:20:03
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_001642775.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_001642775.1_SCS111-2fq_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 37 sequences in 0.0999179 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:20:03
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_014876835.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_014876835.1_ASM1487683v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 49 sequences in 0.122233 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:20:04
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_002835995.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_002835995.1_ASM283599v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 320 sequences in 0.125695 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:20:04
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_014490725.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_014490725.1_ASM1449072v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 17 sequences in 0.102555 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:20:04
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_001296055.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_001296055.1_ASM129605v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 149 sequences in 0.110124 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:20:04
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_001971725.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_001971725.1_ASM197172v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 1 sequences in 0.0843492 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:20:05
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_003355455.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_003355455.1_ASM335545v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 2 sequences in 0.0924439 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:20:05
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_002237735.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_002237735.1_ASM223773v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 31 sequences in 0.144369 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:20:05
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_002813915.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_002813915.1_ASM281391v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 1 sequences in 0.109816 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:20:06
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_018156225.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_018156225.1_ASM1815622v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 133 sequences in 0.181347 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:20:06
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_000238335.3_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_000238335.3_ASM23833v4_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 12 sequences in 0.10323 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:20:06
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_001292705.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_001292705.1_ASM129270v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 113 sequences in 0.113671 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:20:07
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_014077435.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_014077435.1_ASM1407743v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 167 sequences in 0.143246 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:20:07
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_000330925.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_000330925.1_MicAerT1.0_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 4 sequences in 0.146545 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:20:07
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_001558025.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_001558025.1_ASM155802v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 57 sequences in 0.537122 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:20:08
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_003151135.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_003151135.1_ASM315113v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 51 sequences in 0.108399 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:20:08
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_004761885.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_004761885.1_ASM476188v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 115 sequences in 0.14064 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:20:09
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_020514275.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_020514275.1_ASM2051427v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 10 sequences in 0.0718439 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:20:09
# ...
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 276 sequences in 0.0859201 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:30:08
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_001721285.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_001721285.1_PanISTKB1.0_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 115 sequences in 0.188472 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:30:09
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_002330425.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_002330425.1_ASM233042v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 99 sequences in 0.186316 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:30:09
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_003300615.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_003300615.1_ASM330061v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 1119 sequences in 0.105342 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:30:09
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_014850955.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_014850955.1_ASM1485095v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 2 sequences in 0.158244 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:30:10
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_001531025.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_001531025.1_ASM153102v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 99 sequences in 0.216006 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:30:10
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_904845895.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_904845895.1_ASM90484589v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 10 sequences in 0.0836132 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:30:10
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_002883555.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_002883555.1_MPR-R3A_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 132 sequences in 0.18553 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:30:11
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_020171465.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_020171465.1_ASM2017146v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 12 sequences in 1.56609 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:30:13
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_003444655.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_003444655.1_ASM344465v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 1055 sequences in 1.63885 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:30:15
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_008254045.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_008254045.1_ASM825404v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 1 sequences in 4.33776 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:30:19
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_006372085.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_006372085.1_ASM637208v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 214 sequences in 2.26695 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:30:22
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_005040825.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_005040825.1_ASM504082v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 163 sequences in 1.82373 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:30:24
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_900166085.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_900166085.1_11670_1_25_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 44 sequences in 0.101523 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:30:24
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_003198255.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_003198255.1_ASM319825v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 46 sequences in 0.146077 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:30:25
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_004921895.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_004921895.1_ASM492189v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 83 sequences in 0.0970111 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:30:25
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_006379455.2_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_006379455.2_ASM637945v2_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 215 sequences in 0.115935 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:30:25
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_000312465.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_000312465.1_ASM31246v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 171 sequences in 0.149227 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:30:25
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_001440005.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_001440005.1_ASM144000v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 52 sequences in 0.154754 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:30:26
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_008502035.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_008502035.1_CC2_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 31 sequences in 0.133653 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:30:26
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_003449125.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_003449125.1_ASM344912v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 228 sequences in 0.101821 seconds.
#
#
# Building a new DB, current time: 11/09/2021 11:30:26
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_016771835.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_016771835.1_ASM1677183v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 23 sequences in 0.143288 seconds.
# ^C
#
#
# Building a new DB, current time: 11/09/2021 11:30:27
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_000753795.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_000753795.1_ASM75379v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# ^C
#
#
# Building a new DB, current time: 11/09/2021 11:30:27
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_002263325.2_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_002263325.2_ASM226332v2_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# ^C
#
#
# Building a new DB, current time: 11/09/2021 11:30:27
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_014279615.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_014279615.1_ASM1427961v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# ^C
#
#
# Building a new DB, current time: 11/09/2021 11:30:27
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_016653175.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_016653175.1_ASM1665317v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 30 sequences in 0.114962 seconds.
# ^C
#
#
# Building a new DB, current time: 11/09/2021 11:30:28
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_019104745.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_019104745.1_ASM1910474v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# ^C
#
#
# Building a new DB, current time: 11/09/2021 11:30:28
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_000259115.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_000259115.1_ASM25911v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# ^C
#
#
# Building a new DB, current time: 11/09/2021 11:30:28
# New DB name:   /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/quality_control/neg_blast/databases/GCF_002741095.1_db
# New DB title:  /media/manu/RiPP_Prioritiser/RTX_toxin_acyltransferase/base_genomes/temp_neg_genomes/GCF_002741095.1_ASM274109v1_genomic.fna
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# ^C
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/miniconda3/lib/python3.9/site-packages/IPython/utils/_process_posix.py in system(self, cmd)
#     156             else:
# --> 157                 child = pexpect.spawn(self.sh, args=['-c', cmd])  # Vanilla Pexpect
#     158             flush = sys.stdout.flush
#
# ~/miniconda3/lib/python3.9/site-packages/pexpect/pty_spawn.py in __init__(self, command, args, timeout, maxread, searchwindowsize, logfile, cwd, env, ignore_sighup, echo, preexec_fn, encoding, codec_errors, dimensions, use_poll)
#     204         else:
# --> 205             self._spawn(command, args, preexec_fn, dimensions)
#     206         self.use_poll = use_poll
#
# ~/miniconda3/lib/python3.9/site-packages/pexpect/pty_spawn.py in _spawn(self, command, args, preexec_fn, dimensions)
#     302
# --> 303         self.ptyproc = self._spawnpty(self.args, env=self.env,
#     304                                      cwd=self.cwd, **kwargs)
#
# ~/miniconda3/lib/python3.9/site-packages/pexpect/pty_spawn.py in _spawnpty(self, args, **kwargs)
#     314         '''Spawn a pty and return an instance of PtyProcess.'''
# --> 315         return ptyprocess.PtyProcess.spawn(args, **kwargs)
#     316
#
# ~/miniconda3/lib/python3.9/site-packages/ptyprocess/ptyprocess.py in spawn(cls, argv, cwd, env, echo, preexec_fn, dimensions, pass_fds)
#     314         os.close(exec_err_pipe_write)
# --> 315         exec_err_data = os.read(exec_err_pipe_read, 4096)
#     316         os.close(exec_err_pipe_read)
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-10-0c74b156b521> in <module>
#       9 # makes blast databases of all individual neg genomes (easier to keep track of accession numbers than when combining)
#      10 for genomes in neg_genomes_list:
# ---> 11     get_ipython().system('makeblastdb -in "{neg_genomes_path}"/"{genomes}"* -dbtype nucl -out "{neg_blast_db_path}"/"{genomes}"_db')
#      12
#      13 # runs blastn search of all TP genes against all blast databases of negative genomes
#
# ~/miniconda3/lib/python3.9/site-packages/ipykernel/zmqshell.py in system_piped(self, cmd)
#     645                 self.user_ns['_exit_code'] = system(cmd)
#     646         else:
# --> 647             self.user_ns['_exit_code'] = system(self.var_expand(cmd, depth=1))
#     648
#     649     # Ensure new system_piped implementation is used
#
# ~/miniconda3/lib/python3.9/site-packages/IPython/utils/_process_posix.py in system(self, cmd)
#     171             # (the character is known as ETX for 'End of Text', see
#     172             # curses.ascii.ETX).
# --> 173             child.sendline(chr(3))
#     174             # Read and print any more output the program might produce on its
#     175             # way out.
#
# UnboundLocalError: local variable 'child' referenced before assignment

# %%
# Use hmmer to find tp_gene contamination in negative samples
# This is to some extent dependent on which tp genes are chosen. If fewer neg_genomes result from the decontamination
#     process than are specified by select_neg_genomes, it might be worth trying a different set of tp_genes

with open(BGC_path+'/'+'report_2_generate_tp.txt', 'a') as f:
    f.write('\n'+'Using hmmer to check negative genomes for contamination'+'\n\n')

# Build net alignment of tp_genes
# !muscle -in "{BGC_path}"/"{BGC_type}"_selected_tp_genes_altered.fasta -out "{neg_hmm_db_path}"/"{BGC_type}"_selected_tp_gene_alignment.fasta -loga "{BGC_path}"/report_2_generate_tp.txt

with open(BGC_path+'/'+'report_2_generate_tp.txt', 'a') as f:
    f.write('\n'+'Building nucleotide hmm of selected true positive genes'+'\n\n'+'Searching neg genomes with nucleotide hmm.\n\n')

# Build nucleotide based hmm of tp_genes alignment
# !hmmbuild -n tp_nucl_aln --dna "{neg_hmm_db_path}"/"{BGC_type}"_tp_nucl.hmm "{neg_hmm_db_path}"/"{BGC_type}"_selected_tp_gene_alignment.fasta

# Search neg genomes with hmm
for genomes in neg_genomes_list:
    #metaBGC uses these cutoffs for all the protein hmms. This is more stringent/produces fewer results
    # !nhmmer --F1 0.02 --F2 0.02 --F3 0.02 --tblout "{neg_hmm_results_path}"/"{genomes}"_hmm_result.tbl "{neg_hmm_db_path}"/"{BGC_type}"_tp_nucl.hmm "{neg_genomes_path}"/"{genomes}"*
    #This produces more results, should there be a lack of negative genomes.
#    !nhmmer --tblout "{neg_hmm_results_path}"/"{genomes}"_hmm_result.tbl "{neg_hmm_db_path}"/"{BGC_type}"_tp_nucl.hmm "{neg_genomes_path}"/"{genomes}"*

print('Done')

# %%
# Parse hmm output
#https://stackoverflow.com/questions/62012615/convert-a-hmmer-tblout-output-to-a-pandas-dataframe

sample_list = []
id_list=[]
len_list=[]
evalue_list=[]


#Can't parse mhmmer output with biopython at the moment, so did parsing manually.
for filename in os.listdir(neg_hmm_results_path):
    samplename = '_'.join(filename.split('_')[0:2])
    with open(neg_hmm_results_path+'/'+filename) as handle:
        content = handle.readlines()
        for line in content:
            if not line.startswith('#'):
                sample_list.append(samplename)
                id_list.append(line.split()[0])
                len_list.append(int(float(line.split()[5])-float(line.split()[12])))
                evalue_list.append(float(line.split()[12]))

                
       
# Generate hit_df based on found tp_hits in neg genomes
hmm_dict = {'sample': sample_list, 'target_name': id_list, 'length': len_list,  'evalue': evalue_list}             
hit_df = pd.DataFrame.from_dict(hmm_dict)
hit_df.to_csv(neg_hmm_path+'/all_nhmmer_fn_samples.csv', index=False)

#filter hit_df by evalue cutoff
evalue_filter = hit_df['evalue'] <= hmm_evalue_cutoff
cutoff_hit_df = hit_df[evalue_filter]

#deduplicate samples
unique_hit_df = cutoff_hit_df.drop_duplicates(subset='sample', inplace=False)
unique_hit_df.to_csv(quality_control_path+'/nhmmer_elt'+str(hmm_evalue_cutoff)+'_fn_samples.csv', index=False)

# Generate a list of contaminated negative genomes with combined results from blast and hmm hits
hmm_remove_list = list(unique_hit_df.iloc[:,0])
remove_list = blast_remove_list
remove_list.extend(x for x in hmm_remove_list if x not in remove_list)

with open(BGC_path+'/'+'report_2_generate_tp.txt', 'a') as f:
    f.write('\n'+'Contamination with tp_seqs found in samples:\n'+str(hmm_remove_list)+'\n\n'+'Found '+str(len(remove_list))+' total samples with tp contamination in neg genomes.')

# Remove these contaminated samples from the possible pool of negative sequences
cleaned = ~unique_neg_df['assembly'].isin(remove_list)
cleaned_unique_neg_df = unique_neg_df[cleaned]

# Select a preset number of negative genomes (this could lead to fewer genomes available than selected. Handle)
selected_neg_genomes = list(cleaned_unique_neg_df.iloc[:,1])[0:select_neg_genomes]

# report block
with open(BGC_path+'/'+'report_2_generate_tp.txt', 'a') as f:
    f.write('\n\n decontaminated selected_neg_genomes are:\n')
    f.write(str(selected_neg_genomes))

for genome in selected_neg_genomes:
    print('moving negative', genome, 'to', output_neg_path)
    # !mv "{neg_genomes_path}"/"{genome}"* "{output_neg_path}"
    
print('Done')

# %%
# To confirm, run blast on all samples selected as pos genomes

# makes blast databases of all individual neg genomes (easier to keep track of accession numbers than when combining)
for genomes in selected_tp_genomes:
    # !makeblastdb -in "{output_pos_path}"/"{genomes}"* -dbtype nucl -out "{pos_blast_db_path}"/"{genomes}"_db

for genomes in selected_tp_genomes:
    # !blastn -db "{pos_blast_db_path}"/"{genomes}"_db -query "{BGC_path}"/"{BGC_type}"_selected_tp_genes_altered.fasta -out "{pos_blast_results_path}"/"{genomes}".blastout -outfmt "6 qseqid sseqid pident evalue length"
    
# use pandas to concatenate all blast output tables
df_list = []
for outfile in os.listdir(pos_blast_results_path):
    try:
        blast_df = pd.read_csv(pos_blast_results_path+'/'+outfile, sep='\t', names=['qseqid', 'sseqid', 'pident', 'evalue', 'length'], index_col=None)
        blast_df['sample'] = '.'.join(outfile.split('.')[0:2])
        df_list.append(blast_df)
    except EmptyDataError:
        continue
        
# Generate a list of contaminated negative genomes        
pos_blast_hits_df = pd.concat(df_list)
pos_blast_hits_df.to_csv(pos_blast_path+'/blast_results_summary.csv', index=False)

# %%
# To confirm, run nhmmer on all samples selected as pos genomes


# Search neg genomes with hmm
for genomes in selected_tp_genomes:
    # !nhmmer --F1 0.02 --F2 0.02 --F3 0.02 --tblout "{pos_hmm_results_path}"/"{genomes}"_hmm_result.tbl "{neg_hmm_db_path}"/"{BGC_type}"_tp_nucl.hmm "{output_pos_path}"/"{genomes}"*

sample_list = []
id_list=[]
evalue_list=[]
len_list = []

#Can't parse mhmmer output with biopython at the moment, so did parsing manually.
for filename in os.listdir(pos_hmm_results_path):
    samplename = '_'.join(filename.split('_')[0:2])
    with open(pos_hmm_results_path+'/'+filename) as handle:
        content = handle.readlines()
        for line in content:
            if not line.startswith('#'):
                sample_list.append(samplename)
                id_list.append(line.split()[0])
                len_list.append(int(float(line.split()[5])-float(line.split()[12])))
                evalue_list.append(float(line.split()[12]))

                
       
# Generate hit_df based on found tp_hits in neg genomes
hmm_dict = {'sample': sample_list, 'target_name': id_list, 'length': len_list, 'evalue': evalue_list}             
hit_df = pd.DataFrame.from_dict(hmm_dict)
hit_df.to_csv(pos_hmm_path+'/nhmmer_all_pos_samples.csv', index=False)

#deduplicate samples
unique_hit_df = hit_df.drop_duplicates(subset='sample', inplace=False)
unique_hit_df.to_csv(pos_hmm_path+'/nhmmer_unique_pos_samples.csv', index=False)

print('Done')
